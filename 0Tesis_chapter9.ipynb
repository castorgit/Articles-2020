# %% [markdown]
# ## Figures Tesis Chapter 9 CNN nets

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pprint
import json
import numpy as np
import matplotlib.colors
import matplotlib.pyplot as plt
import matplotlib.colors as colors
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Classic Convolutional Architectures

# %% [markdown]
# ### Classic 1 Layer

# %%
query = {"experiment": "JM_CNN_1L_05","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN 2 layers ', font=18, labels=['test','val'],save='CNN_2L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.215977079464214
# StDev (test)= 0.79422365442025
# MEAN (val)= 6.914103793166739
# StDev (val)= 0.7350684930080815

# %% [markdown]
# ### Classic 2 Layers

# %%
query = {"experiment": "JM_CNN_2L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN 2 layers ', font=18, labels=['test','val'],save='CNN_2L_distplot',saveformat='png')
# Out:
# 2000
# MEAN (test)= 7.225768110135355
# StDev (test)= 0.8005374713628273
# MEAN (val)= 6.907983123249421
# StDev (val)= 0.7355034172464132

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_2L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12742
# Method:                          IRLS   Log-Likelihood:                -776.60
# Date:                Tue, 31 Mar 2020   Deviance:                       254.58
# Time:                        14:47:46   Pearson chi2:                     255.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4950      0.075      6.566      0.000       0.347       0.643
# ...

# %% [markdown]
# ### Classic 3 Layers

# %%
query = {"experiment": "JM_CNN_3L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN 3 layers ', font=18, labels=['test','val'],save='CNN_3L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.222775421958853
# StDev (test)= 0.800938320127753
# MEAN (val)= 6.894758287688494
# StDev (val)= 0.7343124541330225

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_3L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13350
# Method:                          IRLS   Log-Likelihood:                -823.22
# Date:                Tue, 31 Mar 2020   Deviance:                       266.73
# Time:                        14:47:49   Pearson chi2:                     267.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5297      0.077      6.866      0.000       0.378       0.681
# ...

# %% [markdown]
# ### Classic 4 Layers

# %%
query = {"experiment": "JM_CNN_4L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN 4 layers ', font=18, labels=['test','val'],save='CNN_4L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.189581095506534
# StDev (test)= 0.8035263770810934
# MEAN (val)= 6.858041511353047
# StDev (val)= 0.7332900243052706

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_4L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13399
# Method:                          IRLS   Log-Likelihood:                -826.90
# Date:                Tue, 31 Mar 2020   Deviance:                       267.71
# Time:                        14:47:51   Pearson chi2:                     268.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4989      0.077      6.480      0.000       0.348       0.650
# ...

# %% [markdown]
# ### CNN Classic 5 Layers

# %%
query = {"experiment": "JM_CNN_5L_MIMO","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN 5 layers ', font=18, labels=['test','val'],save='CNN_5L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.152083690923029
# StDev (test)= 0.8093919601061584
# MEAN (val)= 6.81567060753176
# StDev (val)= 0.7350991059371267

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_5L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13919
# Method:                          IRLS   Log-Likelihood:                -864.99
# Date:                Tue, 31 Mar 2020   Deviance:                       278.11
# Time:                        14:47:54   Pearson chi2:                     278.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4915      0.078      6.317      0.000       0.339       0.644
# ...

# %% [markdown]
# ### Classic CNN 6L

# %%
query = {"experiment": "JM_CNN_6L_MIMO","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN 6 layers ', font=18, labels=['test','val'],save='CNN_6L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.106360350359217
# StDev (test)= 0.8089545636964103
# MEAN (val)= 6.771329562682721
# StDev (val)= 0.7327173413337387

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_6L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13963
# Method:                          IRLS   Log-Likelihood:                -868.15
# Date:                Tue, 31 Mar 2020   Deviance:                       278.99
# Time:                        14:47:57   Pearson chi2:                     279.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4750      0.078      6.115      0.000       0.323       0.627
# ...

# %% [markdown]
# ### Classic CNN 7L

# %%
query = {"experiment": "JM_CNN_7L_MIMO","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN 7 layers ', font=18, labels=['test','val'],save='CNN_7L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.0524391010584235
# StDev (test)= 0.8076598396712453
# MEAN (val)= 6.749846622615074
# StDev (val)= 0.7343488774994985

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_7L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13762
# Method:                          IRLS   Log-Likelihood:                -853.62
# Date:                Tue, 31 Mar 2020   Deviance:                       274.97
# Time:                        14:47:59   Pearson chi2:                     275.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4573      0.077      5.962      0.000       0.307       0.608
# ...

# %% [markdown]
# ### Classic CNN 8L

# %%
query = {"experiment": "JM_CNN_8L_MIMO","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 1999

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN 8 layers ', font=18, labels=['test','val'],save='CNN_8L_distplot',saveformat='png')
# Out:
# MEAN (test)= 5.44995181281984
# StDev (test)= 3.042721223523469
# MEAN (val)= 5.2031102413285835
# StDev (val)= 2.905121055107689

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_8L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 1999
# Model:                            GLM   Df Residuals:                     1997
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.11845
# Method:                          IRLS   Log-Likelihood:                -703.25
# Date:                Tue, 31 Mar 2020   Deviance:                       236.54
# Time:                        14:48:01   Pearson chi2:                     237.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0353      0.016      2.238      0.025       0.004       0.066
# ...

# %% [markdown]
# ## CNN Separable Architectures

# %% [markdown]
# ### CNN sep 1L

# %%
query = {"experiment": "JM_CNN_sep","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN sep 1 layer ', font=18, labels=['test','val'],save='CNN_sep_1L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.300770611159176
# StDev (test)= 0.7976043347984896
# MEAN (val)= 6.991350820234412
# StDev (val)= 0.7522393958362509

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_sep_1L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12581
# Method:                          IRLS   Log-Likelihood:                -763.89
# Date:                Tue, 31 Mar 2020   Deviance:                       251.37
# Time:                        14:48:04   Pearson chi2:                     251.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6603      0.074      8.906      0.000       0.515       0.806
# ...

# %% [markdown]
# ### CNN separable 2L

# %%
query = {"experiment": "JM_CNN_sep_2l_B","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN sep 2 layers ', font=18, labels=['test','val'],save='CNN_sep_2L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.320931027921126
# StDev (test)= 0.7979096196569432
# MEAN (val)= 7.008636432620585
# StDev (val)= 0.7542893131604126

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_sep_2L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12777
# Method:                          IRLS   Log-Likelihood:                -779.32
# Date:                Tue, 31 Mar 2020   Deviance:                       255.28
# Time:                        14:48:06   Pearson chi2:                     255.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6917      0.075      9.260      0.000       0.545       0.838
# ...

# %% [markdown]
# ### CNN sep 3L

# %%
query = {"experiment": "JM_CNN_sep_3l","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN sep 3 layers ', font=18, labels=['test','val'],save='CNN_sep_3L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.301759195389126
# StDev (test)= 0.7957460874531367
# MEAN (val)= 6.9883294035429095
# StDev (val)= 0.7458061735753356

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_sep_3L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13070
# Method:                          IRLS   Log-Likelihood:                -802.06
# Date:                Tue, 31 Mar 2020   Deviance:                       261.15
# Time:                        14:48:09   Pearson chi2:                     261.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6586      0.076      8.645      0.000       0.509       0.808
# ...

# %% [markdown]
# ### CNN sep 4L

# %%
query = {"experiment": "JM_CNN_sep_4l","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN sep 4 layers ', font=18, labels=['test','val'],save='CNN_sep_4L_distplot',saveformat='png')
# Out:
# MEAN (test)= 6.832675006428014
# StDev (test)= 0.8087558110143385
# MEAN (val)= 6.519693567567577
# StDev (val)= 0.7567396481593395

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_sep_4L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.15061
# Method:                          IRLS   Log-Likelihood:                -943.80
# Date:                Tue, 31 Mar 2020   Deviance:                       300.92
# Time:                        14:48:11   Pearson chi2:                     301.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7185      0.075      9.547      0.000       0.571       0.866
# ...

# %% [markdown]
# ### CNN sep 5L

# %%
query = {"experiment": "JM_CNN_sep_5L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 1922

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN sep 5 layers ', font=18, labels=['test','val'],save='CNN_sep_5L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.156712749823947
# StDev (test)= 0.8105298090771417
# MEAN (val)= 6.848242785324778
# StDev (val)= 0.7364555733724911

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_sep_5L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 1922
# Model:                            GLM   Df Residuals:                     1920
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13469
# Method:                          IRLS   Log-Likelihood:                -799.61
# Date:                Tue, 31 Mar 2020   Deviance:                       258.61
# Time:                        14:48:14   Pearson chi2:                     259.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4357      0.078      5.564      0.000       0.282       0.589
# ...

# %% [markdown]
# ### CNN sep 6L

# %%
query = {"experiment": "JM_CNN_sep_6L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN sep 6 layers ', font=18, labels=['test','val'],save='CNN_sep_6L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.1157178783134425
# StDev (test)= 0.8088335488991628
# MEAN (val)= 6.806462946486774
# StDev (val)= 0.7358669257576345

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_sep_6L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13605
# Method:                          IRLS   Log-Likelihood:                -842.16
# Date:                Tue, 31 Mar 2020   Deviance:                       271.83
# Time:                        14:48:16   Pearson chi2:                     272.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4567      0.077      5.952      0.000       0.306       0.607
# ...

# %% [markdown]
# ### CNN sep 7L

# %%
query = {"experiment": "JM_CNN_sep_7L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN sep 7 layers ', font=18, labels=['test','val'],save='CNN_sep_7L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.0539478269330935
# StDev (test)= 0.8087297995411785
# MEAN (val)= 6.749445851454255
# StDev (val)= 0.7362466181961755

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_sep_7L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13700
# Method:                          IRLS   Log-Likelihood:                -849.12
# Date:                Tue, 31 Mar 2020   Deviance:                       273.73
# Time:                        14:48:19   Pearson chi2:                     274.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4612      0.076      6.043      0.000       0.312       0.611
# ...

# %% [markdown]
# ### CNN sep 8L

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN sep 8 layers ', font=18, labels=['test','val'],save='CNN_sep_8L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.0539478269330935
# StDev (test)= 0.8087297995411785
# MEAN (val)= 6.749445851454255
# StDev (val)= 0.7362466181961755

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_sep_8L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13700
# Method:                          IRLS   Log-Likelihood:                -849.12
# Date:                Tue, 31 Mar 2020   Deviance:                       273.73
# Time:                        14:48:20   Pearson chi2:                     274.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4612      0.076      6.043      0.000       0.312       0.611
# ...

# %% [markdown]
# ## CNN with skip connection

# %% [markdown]
# ### CNN Skip 1L

# %%
query = {"experiment": "JM_CNN_1L_SKIP","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN skip 1 layer ', font=18, labels=['test','val'],save='CNN_skip_1L_distplot',saveformat='png')
# Out:
# MEAN (test)= 6.935327239201122
# StDev (test)= 0.7988283997345355
# MEAN (val)= 6.671008462622118
# StDev (val)= 0.7303795092141188

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_skip_1L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12349
# Method:                          IRLS   Log-Likelihood:                -745.25
# Date:                Tue, 31 Mar 2020   Deviance:                       246.73
# Time:                        14:48:22   Pearson chi2:                     247.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3822      0.072      5.294      0.000       0.241       0.524
# ...

# %% [markdown]
# ### CNN skip 2L

# %%
query = {"experiment": "JM_CNN_2L_SKIP","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN skip 2 layers ', font=18, labels=['test','val'],save='CNN_skip_2L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.2228615372300595
# StDev (test)= 0.7981908227717746
# MEAN (val)= 6.9044645678636805
# StDev (val)= 0.7378184227485595

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_skip_2L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12528
# Method:                          IRLS   Log-Likelihood:                -759.69
# Date:                Tue, 31 Mar 2020   Deviance:                       250.31
# Time:                        14:48:25   Pearson chi2:                     250.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5272      0.074      7.078      0.000       0.381       0.673
# ...

# %% [markdown]
# ### CNN skip 3L

# %%
query = {"experiment": "JM_CNN_3L_SKIP","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN skip 3 layers ', font=18, labels=['test','val'],save='CNN_skip_3L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.221268636614315
# StDev (test)= 0.7980067595722375
# MEAN (val)= 6.903105781050659
# StDev (val)= 0.7376426407524693

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_skip_3L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12453
# Method:                          IRLS   Log-Likelihood:                -753.68
# Date:                Tue, 31 Mar 2020   Deviance:                       248.82
# Time:                        14:48:27   Pearson chi2:                     249.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5223      0.074      7.033      0.000       0.377       0.668
# ...

# %% [markdown]
# ### CNN Skip 4L

# %%
query = {"experiment": "JM_CNN_4L_SKIP","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN skip 4 layers ', font=18, labels=['test','val'],save='CNN_skip_4L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.201385774228026
# StDev (test)= 0.8059355061177899
# MEAN (val)= 6.871271230229861
# StDev (val)= 0.7394237070331147

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_skip_4L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.13859
# Method:                          IRLS   Log-Likelihood:                -860.62
# Date:                Tue, 31 Mar 2020   Deviance:                       276.90
# Time:                        14:48:30   Pearson chi2:                     277.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5580      0.078      7.172      0.000       0.406       0.710
# ...

# %% [markdown]
# ### CNN skip 5L

# %%
query = {"experiment": "JM_CNN_5L_SKIP","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN skip 5 layers ', font=18, labels=['test','val'],save='CNN_skip_5L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.1828242752911935
# StDev (test)= 0.8104410298305199
# MEAN (val)= 6.84957418102309
# StDev (val)= 0.738532169267009

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_skip_5L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14115
# Method:                          IRLS   Log-Likelihood:                -878.97
# Date:                Tue, 31 Mar 2020   Deviance:                       282.02
# Time:                        14:48:32   Pearson chi2:                     282.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5219      0.078      6.659      0.000       0.368       0.675
# ...

# %% [markdown]
# ### CNN skip 6L

# %%
query = {"experiment": "JM_CNN_6L_SKIP","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN skip 6 layers ', font=18, labels=['test','val'],save='CNN_skip_6L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.157154316088481
# StDev (test)= 0.8133534826247729
# MEAN (val)= 6.820981116049208
# StDev (val)= 0.7386782616695111

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_skip_6L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14269
# Method:                          IRLS   Log-Likelihood:                -889.78
# Date:                Tue, 31 Mar 2020   Deviance:                       285.09
# Time:                        14:48:35   Pearson chi2:                     285.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5048      0.078      6.435      0.000       0.351       0.659
# ...

# %% [markdown]
# ### CNN skip 7L

# %%
query = {"experiment": "JM_CNN_7L_skip","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 1960

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN skip 7 layers ', font=18, labels=['test','val'],save='CNN_skip_7L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.129590188698342
# StDev (test)= 0.8144448007918265
# MEAN (val)= 6.789764747554228
# StDev (val)= 0.7385814182937502

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_skip_7L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 1960
# Model:                            GLM   Df Residuals:                     1958
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14521
# Method:                          IRLS   Log-Likelihood:                -889.12
# Date:                Tue, 31 Mar 2020   Deviance:                       284.32
# Time:                        14:48:37   Pearson chi2:                     284.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5115      0.080      6.427      0.000       0.356       0.668
# ...

# %% [markdown]
# ### CNN Skip 8L

# %%
query = {"experiment": "JM_CNN_8L_skip","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='CNN skip 8 layers ', font=18, labels=['test','val'],save='CNN_skip_8L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.090304661453285
# StDev (test)= 0.8178861379479077
# MEAN (val)= 6.751250137241301
# StDev (val)= 0.739436444658853

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8),save="CNN_skip_8L_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.14596
# Method:                          IRLS   Log-Likelihood:                -912.43
# Date:                Tue, 31 Mar 2020   Deviance:                       291.62
# Time:                        14:48:39   Pearson chi2:                     292.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4866      0.078      6.202      0.000       0.333       0.640
# ...
