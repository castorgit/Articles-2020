# %% [markdown]
# # Experimental results  Chapter 8 Thesis

# %%
# %load_ext autoreload
# %autoreload

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pprint
import json
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def print_config(name):
# read and print .json file
   with open('e:/Wind/Scripts/MultipleData/configsjm/'+ name + '.json') as json_file:
      data = json.load(json_file)
      pprint.pprint(data)
   return

# %% [markdown]
# ### 8.1 MLP Architecture variants

# %% [markdown]
# ### 8.1 MLP cascade

# %%
query = {"experiment": "JM_MLP_cas_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
print_config('config_MLP_s2s_cas_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.3],
#           'activation_full': ['leaky', 0.3],
#           'batchnorm': True,
#           'drop': 0.4,
#           'full': [1024, 512, 512],
#           'fulldrop': 0.5,
#           'mode': 'MLP_s2s_cas'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5548-12'],
#           'dataset': 'onesitemanyvar',
#           'datasize': 43834,
#           'fraction': 1,
#           'lag': 12,
#           'scaler': 'standard',
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP_cas', font=18, labels=['test','val'],save='MLP_cas_distplot',saveformat='png')
# Out:
# 2000
# MEAN (test)= 7.2504926159947605
# StDev (test)= 0.8011011642044916
# MEAN (val)= 6.928719753975598
# StDev (val)= 0.7369461154955377

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8), save="MLP_cas_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12902
# Method:                          IRLS   Log-Likelihood:                -789.12
# Date:                Thu, 09 Apr 2020   Deviance:                       257.79
# Time:                        11:14:51   Pearson chi2:                     258.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5173      0.076      6.812      0.000       0.368       0.666
# validation     0.9718      0.011     89.163      0.000       0.950       0.993
# ==============================================================================

# %% [markdown]
# ##### see Notebook 0Tesis_chapter_8_SJOINT for SJOINT

# %% [markdown]
# #### Cascade Experiment 8.1.1

# %% [markdown]
# #### 1 Layer

# %%
query = {"experiment": "JM_MLP_1L_cas","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP cas 1L', font=18, labels=['test','val'],save='MLP_1L_cas_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.169598703422317
# StDev (test)= 0.8007394981821492
# MEAN (val)= 6.846941070913188
# StDev (val)= 0.7410733200502553

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8), save="MLP_1L_cas_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12576
# Method:                          IRLS   Log-Likelihood:                -763.48
# Date:                Fri, 10 Apr 2020   Deviance:                       251.26
# Time:                        12:03:21   Pearson chi2:                     251.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5357      0.074      7.269      0.000       0.391       0.680
# validation     0.9689      0.011     90.549      0.000       0.948       0.990
# ==============================================================================

# %%
query = {"experiment": "JM_MLP_1L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP Classic 1L', font=18, labels=['test','val'],save='MLP_1L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.169331465306943
# StDev (test)= 0.8030632253587582
# MEAN (val)= 6.845841583947987
# StDev (val)= 0.7416301696442196

# %% [markdown]
# #### 2 Layers

# %%
query = {"experiment": "JM_MLP_2L_cas","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP cas 2L', font=18, labels=['test','val'],save='MLP_2L_cas_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.2532195727657705
# StDev (test)= 0.7957120606625689
# MEAN (val)= 6.948116319275233
# StDev (val)= 0.734197013528734

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8), save="MLP_2L_cas_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12222
# Method:                          IRLS   Log-Likelihood:                -734.90
# Date:                Fri, 10 Apr 2020   Deviance:                       244.19
# Time:                        12:03:26   Pearson chi2:                     244.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4878      0.074      6.558      0.000       0.342       0.634
# validation     0.9737      0.011     91.451      0.000       0.953       0.995
# ==============================================================================

# %%
query = {"experiment": "JM_MLP_2L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP Classic 2L', font=18, labels=['test','val'],save='MLP_2L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.2530281235793055
# StDev (test)= 0.7926553356156472
# MEAN (val)= 6.952575986201744
# StDev (val)= 0.7312102511394383

# %% [markdown]
# ##### 3 Layers

# %%
query = {"experiment": "JM_MLP_3L_cas","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP cas 3L', font=18, labels=['test','val'],save='MLP_3L_cas_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.250265518162407
# StDev (test)= 0.7975602665563116
# MEAN (val)= 6.940634931250065
# StDev (val)= 0.7386597026892056

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8), save="MLP_3L_cas_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12099
# Method:                          IRLS   Log-Likelihood:                -724.85
# Date:                Fri, 10 Apr 2020   Deviance:                       241.74
# Time:                        12:03:31   Pearson chi2:                     242.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5057      0.073      6.880      0.000       0.362       0.650
# validation     0.9718      0.011     92.286      0.000       0.951       0.992
# ==============================================================================

# %%
query = {"experiment": "JM_MLP_3L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP_cas', font=18, labels=['test','val'],save='MLP_3L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.211016112719159
# StDev (test)= 0.79356408505507
# MEAN (val)= 6.925519773094735
# StDev (val)= 0.7337490060573401

# %% [markdown]
# ### 4 Layers

# %%
query = {"experiment": "JM_MLP_4L_cas","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP cas 4L', font=18, labels=['test','val'],save='MLP_4L_cas_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.232694407147607
# StDev (test)= 0.8000026856824551
# MEAN (val)= 6.9215709371741285
# StDev (val)= 0.7412065580989154

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8), save="MLP_4L_cas_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12100
# Method:                          IRLS   Log-Likelihood:                -724.87
# Date:                Fri, 10 Apr 2020   Deviance:                       241.75
# Time:                        12:03:36   Pearson chi2:                     242.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5044      0.073      6.905      0.000       0.361       0.648
# validation     0.9721      0.010     92.634      0.000       0.952       0.993
# ==============================================================================

# %%
query = {"experiment": "JM_MLP_4L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP 4L', font=18, labels=['test','val'],save='MLP_3L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.181239979373582
# StDev (test)= 0.7917274768069831
# MEAN (val)= 6.898016337502435
# StDev (val)= 0.7321456093273042

# %% [markdown]
# #### 5 Layers

# %%
query = {"experiment": "JM_MLP_5L_cas","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP cas 5L', font=18, labels=['test','val'],save='MLP_5L_cas_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.215587309956243
# StDev (test)= 0.800234868120114
# MEAN (val)= 6.902746001833986
# StDev (val)= 0.7437624075387865

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8), save="MLP_5L_cas_densplot", saveformat="png")
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   test   No. Observations:                 2000
# Model:                            GLM   Df Residuals:                     1998
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               identity   Scale:                         0.12285
# Method:                          IRLS   Log-Likelihood:                -740.11
# Date:                Fri, 10 Apr 2020   Deviance:                       245.46
# Time:                        12:03:42   Pearson chi2:                     245.
# No. Iterations:                     3   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5382      0.073      7.357      0.000       0.395       0.682
# validation     0.9673      0.011     91.799      0.000       0.947       0.988
# ==============================================================================

# %%
query = {"experiment": "JM_MLP_5L","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='MLP Classic 5L7', font=18, labels=['test','val'],save='MLP_5L_distplot',saveformat='png')
# Out:
# MEAN (test)= 7.110822273279583
# StDev (test)= 0.7852458241467842
# MEAN (val)= 6.848095725185418
# StDev (val)= 0.7271766356380202

# %%
query1 = {"experiment": "JM_MLP_1L_cas","status":"done"}
query2 = {"experiment": "JM_MLP_2L_cas","status":"done"}
query3 = {"experiment": "JM_MLP_3L_cas","status":"done"}
query4 = {"experiment": "JM_MLP_4L_cas","status":"done"}
query5 = {"experiment": "JM_MLP_5L_cas","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_multiple([query1,query2,query3,query4,query5])
results.selected_size()
# Out:
# 2000

# %%
results.compare_ANOVA(labels=["Cas 1L","Cas 2L","Cas 3L","Cas 4L","Cas 5L"])
# Out:
# One-way ANOVA Test set
# =============
# F value: 3.640776324819066
# P value: 0.00572162381096994
#
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ============================================
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
# Cas 1L Cas 2L  0.0836   0.0147 0.1526  True
# Cas 1L Cas 3L  0.0807   0.0117 0.1496  True
# Cas 1L Cas 4L  0.0631  -0.0058 0.132  False
# Cas 1L Cas 5L  0.046   -0.0229 0.1149 False
# Cas 2L Cas 3L  -0.003  -0.0719 0.066  False
# Cas 2L Cas 4L -0.0205  -0.0895 0.0484 False
# Cas 2L Cas 5L -0.0376  -0.1066 0.0313 False
# Cas 3L Cas 4L -0.0176  -0.0865 0.0514 False
# Cas 3L Cas 5L -0.0347  -0.1036 0.0343 False
# Cas 4L Cas 5L -0.0171   -0.086 0.0518 False
# --------------------------------------------
#
# One-way ANOVA Validation set
# =============
# F value: 3.640776324819066
# P value: 0.00572162381096994
#
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ============================================
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
# Cas 1L Cas 2L  0.1012   0.0373 0.165   True
# Cas 1L Cas 3L  0.0937   0.0299 0.1575  True
# Cas 1L Cas 4L  0.0746   0.0108 0.1385  True
# Cas 1L Cas 5L  0.0558   -0.008 0.1196 False
# Cas 2L Cas 3L -0.0075  -0.0713 0.0564 False
# Cas 2L Cas 4L -0.0265  -0.0904 0.0373 False
# Cas 2L Cas 5L -0.0454  -0.1092 0.0185 False
# Cas 3L Cas 4L -0.0191  -0.0829 0.0448 False
# Cas 3L Cas 5L -0.0379  -0.1017 0.026  False
# Cas 4L Cas 5L -0.0188  -0.0827 0.045  False
# --------------------------------------------

# %% [markdown]
# ## 8.2 RNN Experiments

# %% [markdown]
# ### RNN ED s2s GRU

# %%
query = {"experiment": "JM_RNN_ED","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()

# %%
print_config('config_RNN_ED_s2s_JM')

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='RNN ED s2s GRU', font=18, labels=['test','val'],save='RNN_ED_s2s_GRU',saveformat='png')

# %%
results.plot_densplot(plot='regression',glm=True, figsize=(8,8), save="RNN_ED_densplot", saveformat="png")

# %% [markdown]
# ## RNN s2s LSTM

# %%
query = {"experiment": "JM_RNN_s2s_LSTM","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()

# %%
print_config('config_RNN_s2s_LSTM')

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='RNN s2s LSTM', font=18, labels=['test','val'],save='RNN_s2s_LSTM',saveformat='png')

# %% [markdown]
# ## RNN ED s2s LSTM

# %%
query = {"experiment": "JM_RNN_ED_LSTM","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()

# %%
print_config('config_RNN_ED_s2s_LSTM')

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='RNN ED s2s LSTM', font=18, labels=['test','val'],save='RNN_ED_s2s_LSTM',saveformat='png')

# %% [markdown]
# ## RNN s2s GRU

# %%
query = {"experiment": "JM_RNN_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()

# %%
print_config('config_RNN_s2s_JM')

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='RNN s2s GRU', font=18, labels=['test','val'])
# este es igual que el RNN s2s GRU no se salva

# %% [markdown]
# ### RNN s2s GRU

# %%
query = {"experiment": "JM_RNN_s2s_GRU","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()

# %%
print_config('config_RNN_s2s_GRU')

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='RNN s2s GRU', font=18, labels=['test','val'],save='RNN_s2s_GRU',saveformat='png')

# %% [markdown]
# ### ATT GRU

# %%
query = {"experiment": "JM_RNN_GRU_att","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()

# %%
print_config('config_RNN_s2s_GRU')

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='RNN s2s Attention GRU', font=18, labels=['test','val'],save='RNN_s2s_att_GRU',saveformat='png')

# %% [markdown]
# ### ATT LSTM

# %%
query = {"experiment": "JM_RNN_LSTM_att","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()

# %%
print_config('config_RNN_s2s_LSTM')

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='RNN s2s Attention LSTM', font=18, labels=['test','val'],save='RNN_s2s_att_LSTM',saveformat='png')

# %% [markdown]
# ### 8.3 Experiments with Higher Frequency Series

# %% [markdown]
# #### Persistence

# %%
query = {"experiment": "JM_Persistence_02_5m","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
print_config('config_persistence_5m')
# Out:
# {'_id': '00000000',
#  'arch': {'mode': 'persistence'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['54-27274-01'],
#           'dataset': 0,
#           'datasize': 526008,
#           'lag': 18,
#           'scaler': 'standard',
#           'testsize': 210408,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {}}

# %%
results.plot_distplot(dset=('test', 'val'),figsize=(8,8), title='RNN s2s Attention LSTM', font=18, labels=['test','val'],save='RNN_s2s_att_LSTM',saveformat='png')
# Out:
# MEAN (test)= 10.946221664103913
# StDev (test)= 0.343556166037185
# MEAN (val)= 10.749256684087815
# StDev (val)= 0.4359472965282758

# %% [markdown]
# ### MLP 5m 1h

# %%
query = {"experiment": "JM_MLP_5m_1h","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
print_config('config_MLP_5m_1h')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.4,
#           'full': [1024, 512],
#           'mode': 'MLP_s2s'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['54-27274-01'],
#           'dataset': 1,
#           'datasize': 526008,
#           'lag': 120,
#           'scaler': 'standard',
#           'testsize': 210408,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=(['test','val']), figsize=(8,8))
# Out:
# MEAN (test)= 11.123110041914195
# StDev (test)= 0.26672608901208833
# MEAN (val)= 10.950978900085858
# StDev (val)= 0.34653201155496444

# %%
results.plot_hours_boxplot(title = 'MLP Prediction 1 hour ahead',save= "Boxplot_MLP_5m", dset=('test'), saveformat = 'pdf', figsize=(10,6))

# %% [markdown]
# ### MLP 5m 12 hours ahead

# %%
query = {"experiment": "JM_MLP_5m_12h","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
print_config('config_MLP_s2s_5m_12h')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s'},
#  'data': {'aggregate': {'step': 12, 'y': {'method': 'average', 'step': 12}},
#           'ahead': [1, 144],
#           'datanames': ['54-27274-01'],
#           'dataset': 'onesitemanyvar',
#           'datasize': 526008,
#           'fraction': 1,
#           'lag': 144,
#           'scaler': 'standard',
#           'slice': 1,
#           'testsize': 210408,
#           'vars': 'all'},
#  'experiment': 'MLP_2L_5m_12h',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=(['test','val']), figsize=(8,8))
# Out:
# MEAN (test)= 7.408763509128266
# StDev (test)= 0.7749011931787776
# MEAN (val)= 7.094670131025276
# StDev (val)= 0.7243137745758044

# %% [markdown]
# ### MLP 5m 12h future

# %%
query = {"experiment": "JM_MLP_5m_12h_fut","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
print_config('config_MLP_s2s_5m_12h_fut')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_fut'},
#  'data': {'aggregate': {'step': 12, 'y': {'method': 'average', 'step': 12}},
#           'ahead': [1, 144],
#           'datanames': ['54-27274-01'],
#           'dataset': 'onesitemanyvar',
#           'datasize': 526008,
#           'dmatrix': 'future',
#           'fraction': 1,
#           'lag': 144,
#           'scaler': 'standard',
#           'slice': 1,
#           'testsize': 210408,
#           'vars': 'all',
#           'varsf': [2]},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=(['test','val']), figsize=(8,8))
# Out:
# MEAN (test)= 8.02550984976425
# StDev (test)= 0.7535906182315589
# MEAN (val)= 7.74754911553163
# StDev (val)= 0.7330564820427727
