# %% [markdown]
# ### SJOINT analysis different slices

# %%
# %load_ext autoreload
# %autoreload

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pprint
import json
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def print_config(name):

   with open('e:/Wind/Scripts/MultipleData/configsjm/'+ name + '.json') as json_file:
      data = json.load(json_file)
      pprint.pprint(data)

   return

# %% [markdown]
# ### Slice 1 (DIRECT REGRESSION)

# %%
print_config('config_MLP_s2s_sjoint_01')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['elu', 0.2],
#           'drop': 0.0,
#           'full': [1024, 256, 128],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 1,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 1,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_01","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 01', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_01')
# Out:
# 2000
# [6.36143944 7.71216488 6.93065976 ... 7.72352919 6.59414533 8.07484904]
# MEAN (test)= 6.602688941851893
# StDev (test)= 0.8009700290843764
# MEAN (val)= 6.3301379733446135
# StDev (val)= 0.7082851592150909

# %% [markdown]
# ### SLICE 2

# %%
print_config('config_MLP_s2s_sjoint_02')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['elu', 0.2],
#           'drop': 0.0,
#           'full': [1024, 256, 128],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 2,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 1,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_02","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 02', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_02')
# Out:
# 2000
# [4.30127585 6.34985601 6.48458104 ... 7.24705897 6.60162718 6.53496491]
# MEAN (test)= 6.629138195174341
# StDev (test)= 0.8013439534699568
# MEAN (val)= 6.353975181487078
# StDev (val)= 0.7094596270259281

# %% [markdown]
# ### Slice 03

# %%
print_config('config_MLP_s2s_sjoint_03')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['elu', 0.2],
#           'drop': 0.0,
#           'full': [1024, 256, 128],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 3,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 1,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_03","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 03', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_03')
# Out:
# 2000
# [6.32505952 7.93481701 6.52205842 ... 5.23666047 6.31827667 6.57068725]
# MEAN (test)= 6.627393641653719
# StDev (test)= 0.8022830367650187
# MEAN (val)= 6.351430436283646
# StDev (val)= 0.7103831110477256

# %% [markdown]
# ### Slice 04

# %%
print_config('config_MLP_s2s_sjoint_04')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['elu', 0.2],
#           'drop': 0.0,
#           'full': [1024, 256, 128],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 4,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 1,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_04","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 04', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_04')
# Out:
# 2000
# [6.48035116 6.08630107 8.23707454 ... 7.2146993  6.11303198 7.7917177 ]
# MEAN (test)= 6.624702448305137
# StDev (test)= 0.8019448934852943
# MEAN (val)= 6.348661026511829
# StDev (val)= 0.7103522520287675

# %% [markdown]
# ### Slice 06

# %%
print_config('config_MLP_s2s_sjoint')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['elu', 0.2],
#           'drop': 0.0,
#           'full': [1024, 256, 128],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 6,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 1,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 06', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_06')
# Out:
# 2000
# [6.2148009  7.35556517 6.34624072 ... 6.13134369 6.81576739 6.74540575]
# MEAN (test)= 6.608029579571342
# StDev (test)= 0.8041766377581279
# MEAN (val)= 6.333077455636665
# StDev (val)= 0.7091278978731435
