# %% [markdown]
# ### SJOINT analysis different slices

# %%
# %load_ext autoreload
# %autoreload

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pprint
import json
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def print_config(name):

   with open('e:/Wind/Scripts/MultipleData/configsjm/'+ name + '.json') as json_file:
      data = json.load(json_file)
      pprint.pprint(data)

   return

# %% [markdown]
# ### Direct regression own algorithm

# %%
query = {"experiment": "JM_MLP_dir_reg_01","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
print_config('config_MLP_dir_reg')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_dir_reg'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 'onesitemanyvar',
#           'datasize': 43834,
#           'fraction': 1,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 1,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Direct Regression', font=18, labels=['test','val'],saveformat='png', save='MLP_dir_reg')
# Out:
# 2000
# [6.97708475 7.95471609 8.58117823 ... 7.48240679 7.37610088 7.06532895]
# MEAN (test)= 7.241599148439675
# StDev (test)= 0.7906877780295972
# MEAN (val)= 6.937516098852188
# StDev (val)= 0.733324299878811

# %% [markdown]
# ### Slice 1 (DIRECT REGRESSION)

# %%
print_config('config_MLP_s2s_sjoint_01_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 1,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_01_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 01', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_01')
# Out:
# 2000
# [8.46023033 5.36243622 5.39322913 ... 7.3060446  8.15512962 7.60719741]
# MEAN (test)= 7.241013262415615
# StDev (test)= 0.7910690626467909
# MEAN (val)= 6.938103479606939
# StDev (val)= 0.7331743015118114

# %% [markdown]
# ### SLICE 2

# %%
print_config('config_MLP_s2s_sjoint_02_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 2,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_02_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 02', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_02')
# Out:
# 2000
# [8.48003515 7.54282044 6.2159016  ... 4.33365822 7.22107646 7.6603103 ]
# MEAN (test)= 7.2478620155321485
# StDev (test)= 0.7898207600927786
# MEAN (val)= 6.943126461868425
# StDev (val)= 0.7315864594004183

# %% [markdown]
# ### Slice 03

# %%
print_config('config_MLP_s2s_sjoint_03_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 3,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_03_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 03', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_03')
# Out:
# 2000
# [6.4249975  7.89280034 7.18689502 ... 6.06201691 6.40177973 7.50059646]
# MEAN (test)= 7.25237144993547
# StDev (test)= 0.7884638635131458
# MEAN (val)= 6.947419500047687
# StDev (val)= 0.7309820922582814

# %% [markdown]
# ### Slice 04

# %%
print_config('config_MLP_s2s_sjoint_04_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 4,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_04_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 04', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_04')
# Out:
# 2000
# [7.05012192 7.76191589 6.26213995 ... 8.05181097 6.00746414 6.52907641]
# MEAN (test)= 7.255182098847643
# StDev (test)= 0.7881102253889
# MEAN (val)= 6.949340332467494
# StDev (val)= 0.7297851537266955

# %% [markdown]
# ### Slice 06

# %%
print_config('config_MLP_s2s_sjoint_06_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 6,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_06_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 06', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_06')
# Out:
# 2000
# [7.58670431 6.66433624 6.54355119 ... 7.441924   7.61225568 7.55957957]
# MEAN (test)= 7.257398657618388
# StDev (test)= 0.7895768590055305
# MEAN (val)= 6.953231705781383
# StDev (val)= 0.7300070440809948

# %% [markdown]
# ### Slice 12

# %%
print_config('config_MLP_s2s_sjoint_12_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 12,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_12_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 12', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_12')
# Out:
# 2000
# [8.33169076 8.46423299 7.47603544 ... 7.29624908 7.46911473 7.61391143]
# MEAN (test)= 7.253361439188527
# StDev (test)= 0.7924963472512218
# MEAN (val)= 6.951339087250861
# StDev (val)= 0.7306458875559932
