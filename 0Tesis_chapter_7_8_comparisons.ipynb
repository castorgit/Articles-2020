# %% [markdown]
# ### Comparaciones capitulos 7,8 tesis

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
import matplotlib.pyplot as plt
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### MLP series 5 m vs MLP con fut

# %%
query1 = {"experiment": "JM_MLP_5m_12h", "status":"done"}
query2 = {"experiment": "JM_MLP_5m_12h_fut", "status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 2000

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(14,10), title='MLP s(5m) 12h ahead vs MLP s(5m) 12h ahead with fut', labels=['MLP 5m 12h', 'MLP 5m 12h fut'], font=15, save='Boxplot_MLP_5m_vs_MLP_5m_fut', saveformat = 'png')

# %% [markdown]
# ### comparison series 5m con series 1h mlp

# %%
query1 = {"experiment": "JM_MLP_s2s_best", "status":"done"}
query2 = {"experiment": "JM_MLP_5m_12h", "status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 2000

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(14,10), title='MLP series 1h vs MLP series 5m', labels=['MLP series 1h', 'MLP series 5m'], font=15, save='Boxplot_MLP_1h_vs_MLP_5m', saveformat = 'png')

# %% [markdown]
# ### MLP y mLP fut comparison

# %%
query1 = {"experiment": "JM_MLP_s2s_best", "status":"done"}
query2 = {"experiment": "JM_MLP_s2s_fut", "status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 2000

# %%
results.plot_hours_boxplot_compare(dset=('test'), figsize=(14,10), title='MLP vs MLP fut', labels=['MLP series', 'MLP series with fut variable'], font=15, save='Boxplot_MLP_vs_MLP_fut', saveformat = 'png')
