# %% [markdown]
# ### Analysis of prediction short term (5m to 1h) using a wind series sampled every 5 min

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### MLP prediction 12 steps (5 hours)

# %%
query = {"experiment": "JM_MLP_5m","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 1929

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=(['test','val']), figsize=(8,8))
# Out:
# MEAN (test)= 10.942784699228762
# StDev (test)= 0.34513870274366343
# MEAN (val)= 10.744980364618078
# StDev (val)= 0.43984060788704804

# %%
results.plot_hours_boxplot(title = 'MLP Prediction 1 hour ahead',save= "Boxplot_MLP_5m", dset=('test'), saveformat = 'pdf', figsize=(10,6))

# %% [markdown]
# ### Persistence is the baseline

# %%
query = {"experiment": "JM_Persistence_5m","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 1929

# %%
results.plot_distplot(seaborn=True, notebook=True, summary='sum',dset=(['test','val']), figsize=(8,8))
# Out:
# MEAN (test)= 10.942784699228762
# StDev (test)= 0.34513870274366343
# MEAN (val)= 10.744980364618078
# StDev (val)= 0.43984060788704804

# %%
results.plot_hours_boxplot(title = 'MLP Prediction 1 hour ahead',save= "Boxplot_MLP_5m", dset=('test'), saveformat = 'pdf', figsize=(10,6))

# %%
query1 = {"experiment": "JM_Persistence_5m","status":"done"}
query2 = {"experiment": "JM_MLP_5m","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results_compare(query1, query2)
results.selected_size()
# Out:
# 1929

# %%
results.plot_hours_boxplot_compare(title = 'Comparison Persistence with MLP in 5 minutes series',save= "Boxplot_Pers_MLP_5m", dset=('test'), saveformat = 'pdf', figsize=(10,6))

# %%
results.plot_hours_boxplot_compare(title = 'Comparison Persitence with MLP in 5 minutes series',save= "Boxplot_Pers_MLP_5m", dset=('val'), saveformat = 'pdf', figsize=(10,6))
