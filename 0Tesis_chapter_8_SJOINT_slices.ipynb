# %% [markdown]
# ##  Experimental results  Chapter 8 Thesis

# %% [markdown]
# ### SJOINT analysis of different slices

# %%
# %load_ext autoreload
# %autoreload

# %%
from Wind.Results import DBResults
from Wind.Private.DBConfig import mongoremote,mongolocal,mongolocaltest
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pprint
import json
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def print_config(name):

   with open('e:/Wind/Scripts/MultipleData/configsjm/'+ name + '.json') as json_file:
      data = json.load(json_file)
      pprint.pprint(data)

   return

# %% [markdown]
# ### Direct regression own algorithm

# %%
query = {"experiment": "JM_MLP_dir_reg_01","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
print_config('config_MLP_dir_reg')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_dir_reg'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 'onesitemanyvar',
#           'datasize': 43834,
#           'fraction': 1,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 1,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Direct Regression', font=18, labels=['test','val'],saveformat='png', save='MLP_dir_reg')
# Out:
# 2000
# MEAN (test)= 7.241599148439675
# StDev (test)= 0.7906877780295973
# MEAN (val)= 6.937516098852188
# StDev (val)= 0.733324299878811

# %% [markdown]
# ### Slice 1 (DIRECT REGRESSION)

# %%
print_config('config_MLP_s2s_sjoint_01_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 1,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_01_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 01', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_01_distplot')
# Out:
# 2000
# MEAN (test)= 7.241013262415614
# StDev (test)= 0.7910690626467909
# MEAN (val)= 6.938103479606939
# StDev (val)= 0.7331743015118114

# %%
results.plot_densplot(plot='regression',glm=False, figsize=(8,8), save = 'MLP_SJOIN_01_densplot', saveformat='png' )

# %% [markdown]
# ### SLICE 2

# %%
print_config('config_MLP_s2s_sjoint_02_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 2,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_02_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 02', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_02_distplot')
# Out:
# 2000
# MEAN (test)= 7.247862015532148
# StDev (test)= 0.7898207600927786
# MEAN (val)= 6.943126461868425
# StDev (val)= 0.7315864594004183

# %%
results.plot_densplot(plot='regression',glm=False, figsize=(8,8), save = 'MLP_SJOIN_02_densplot', saveformat='png' )

# %% [markdown]
# ### Slice 03

# %%
print_config('config_MLP_s2s_sjoint_03_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 3,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_03_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 03', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_03_distplot')
# Out:
# 2000
# MEAN (test)= 7.25237144993547
# StDev (test)= 0.7884638635131458
# MEAN (val)= 6.947419500047687
# StDev (val)= 0.7309820922582814

# %%
results.plot_densplot(plot='regression',glm=False, figsize=(8,8), save = 'MLP_SJOIN_03_densplot', saveformat='png' )

# %% [markdown]
# ### Slice 04

# %%
print_config('config_MLP_s2s_sjoint_04_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 4,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_04_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 04', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_04_distplot')
# Out:
# 2000
# MEAN (test)= 7.2551820988476425
# StDev (test)= 0.7881102253889
# MEAN (val)= 6.949340332467494
# StDev (val)= 0.7297851537266955

# %%
results.plot_densplot(plot='regression',glm=False, figsize=(8,8), save = 'MLP_SJOIN_04_densplot', saveformat='png' )

# %% [markdown]
# ### Slice 06

# %%
print_config('config_MLP_s2s_sjoint_06_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 6,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_06_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 06', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_06_distplot')
# Out:
# 2000
# MEAN (test)= 7.257398657618388
# StDev (test)= 0.7895768590055305
# MEAN (val)= 6.953231705781383
# StDev (val)= 0.7300070440809948

# %%
results.plot_densplot(plot='regression',glm=False, figsize=(8,8), save = 'MLP_SJOIN_06_densplot', saveformat='png' )

# %% [markdown]
# ### Slice 12

# %%
print_config('config_MLP_s2s_sjoint_12_best')
# Out:
# {'_id': '00000000',
#  'arch': {'activation': ['leaky', 0.2],
#           'drop': 0.3,
#           'full': [512, 256],
#           'mode': 'MLP_s2s_sjoint'},
#  'data': {'ahead': [1, 12],
#           'datanames': ['11-5794-12'],
#           'dataset': 1,
#           'datasize': 43834,
#           'lag': 12,
#           'scaler': 'standard',
#           'slice': 12,
#           'testsize': 17534,
#           'vars': 'all'},
#  'experiment': 'TEST',
#  'training': {'batch': 1024,
#               'epochs': 200,
#               'iter': 1,
#               'lrate': 0.001,
#               'optimizer': 'adamax',
#               'patience': 10}}

# %%
query = {"experiment": "JM_MLP_SJOINT_12_best","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP Sjoin slice 12', font=18, labels=['test','val'],saveformat='png', save='MLP_SJOIN_12_distplot')
# Out:
# 2000
# MEAN (test)= 7.253361439188527
# StDev (test)= 0.7924963472512218
# MEAN (val)= 6.951339087250861
# StDev (val)= 0.7306458875559932

# %%
results.plot_densplot(plot='regression',glm=False, figsize=(8,8), save = 'MLP_SJOIN_12_densplot', saveformat='png' )

# %% [markdown]
# ### Some analysis on the similarity of distributions

# %%
query = {"experiment": "JM_MLP_dir_reg_01","status":"done"}
results = DBResults(conn=mongolocal)
results.retrieve_results(query)
results.selected_size()
# Out:
# 2000

# %%
results.plot_distplot(seaborn=True, dset=('test', 'val'),figsize=(8,8), title='MLP direct regression', font=18, labels=['test','val'])
# Out:
# MEAN (test)= 7.241599148439676
# StDev (test)= 0.7906877780295973
# MEAN (val)= 6.937516098852187
# StDev (val)= 0.733324299878811

# %% [markdown]
# #### ANOVA test

# %%
query1 = {"experiment": "JM_MLP_SJOINT_01_best","status":"done"}
query2 = {"experiment": "JM_MLP_SJOINT_02_best","status":"done"}
query3 = {"experiment": "JM_MLP_SJOINT_03_best","status":"done"}
query4 = {"experiment": "JM_MLP_SJOINT_04_best","status":"done"}
query5 = {"experiment": "JM_MLP_SJOINT_06_best","status":"done"}
query6 = {"experiment": "JM_MLP_SJOINT_12_best","status":"done"}

query41 = {"experiment": "JM_MLP_dir_reg","status":"done"}
#query10 = {"experiment": "JM_MLP_s2s_best","status":"done"}
query11 = {"experiment": "JM_MLP_rec_01","status":"done"}
#query6 = {"experiment": "JM_MLP_dir_reg_01","status":"done"}

query66 = {"experiment": "JM_MLP_1L","status":"done"}
query61 = {"experiment": "JM_MLP_dir_reg_01","status":"done"}
results = DBResults(conn=mongolocaltest)
results.retrieve_results_multiple([query1, query2, query3, query4, query5, query6])
results.selected_size()
# Distributions are too similar. New tests with different parameters should be performed.
# Out:
# 2000

# %%
results.sample(1)
results.selected_size()

results.compare_ANOVA(labels=["01","02","03","04","05","06",])
# Out:
# 2000
# One-way ANOVA Test set
# ...
# F value: 0.11227834541891449
# P value: 0.9897002210222533
#
# Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
# group1 group2 meandiff  lower  upper  reject
# --------------------------------------------
#   01     02    0.0068  -0.0644 0.0781 False
#   01     03    0.0114  -0.0599 0.0826 False
#   01     04    0.0142   -0.057 0.0854 False
#   01     05    0.0164  -0.0548 0.0876 False
#   01     06    0.0123  -0.0589 0.0836 False
#   02     03    0.0045  -0.0667 0.0757 False
#   02     04    0.0073  -0.0639 0.0785 False
#   02     05    0.0095  -0.0617 0.0807 False
#   02     06    0.0055  -0.0657 0.0767 False
#   03     04    0.0028  -0.0684 0.074  False
#   03     05    0.005   -0.0662 0.0762 False
#   03     06    0.001   -0.0702 0.0722 False
#   04     05    0.0022   -0.069 0.0734 False
#   04     06   -0.0018   -0.073 0.0694 False
#   05     06    -0.004  -0.0753 0.0672 False
# --------------------------------------------
#
# ...
